# %% [markdown]
# <a href="https://colab.research.google.com/github/Bran04don/DataScience_Experimentation/blob/main/TheMovieDatabase_01_TopRated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
id = "[api_key]"

# %%
requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key="+id)
# Out:
# <Response [200]>

# %%
response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key="+id)

# %%
data = pd.DataFrame(response.json()['results'])

# %%
data.head()
# Out:
#    adult                     backdrop_path        genre_ids     id  \
# 0  False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg         [18, 80]    278
# 1  False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg  [35, 18, 10749]  19404
# 2  False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg         [18, 80]    238
# 3  False  /loRmRzQXZeqG78TqZuyvSlEQfZb.jpg  [18, 36, 10752]    424
# 4  False  /poec6RqOKY9iSiIUmfyfPfiLtvB.jpg         [18, 80]    240
#
#   original_language                original_title  \
# 0                en      The Shawshank Redemption
# 1                hi  दिलवाले दुल्हनिया ले जायेंगे
# 2                en                 The Godfather
# 3                en              Schindler's List
# 4                en        The Godfather: Part II
#
#                                             overview  popularity  \
# 0  Framed in the 1940s for the double murder of h...      69.679
# 1  Raj is a rich, carefree, happy-go-lucky second...      22.605
# ...

# %%
data.tail()
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 15  False  /l6hQWH9eDksNJNiXWYRkWqikOdu.jpg      [14, 18, 80]     497
# 16  False  /6fA9nie4ROlkyZAUlgKNjGNCbHG.jpg  [18, 28, 80, 53]     155
# 17  False  /fQq1FWp1rC89xDrRMuyFJdFUdMd.jpg       [10749, 35]  761053
# 18  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]     680
# 19  False  /x4biAVdPVCghBlsVIzB6NmbghIz.jpg              [37]     429
#
#    original_language                   original_title  \
# 15                en                   The Green Mile
# 16                en                  The Dark Knight
# 17                en      Gabriel's Inferno: Part III
# 18                en                     Pulp Fiction
# 19                it  Il buono, il brutto, il cattivo
#
#                                              overview  popularity  \
# 15  A supernatural tale set on death row in a Sout...      63.465
# 16  Batman raises the stakes in his war on crime. ...      79.673
# ...

# %%
data.describe()
# Out:
#                   id  popularity  vote_average   vote_count
# count      20.000000   20.000000     20.000000     20.00000
# mean   268817.950000   52.170100      8.545000   9157.90000
# std    318729.652363   37.816833      0.075915   8440.89674
# min       129.000000    9.242000      8.500000    230.00000
# 25%       361.250000   26.629500      8.500000   1301.75000
# 50%     10042.000000   49.399500      8.500000   7722.50000
# 75%    566949.750000   66.658000      8.600000  13871.75000
# max    761053.000000  176.455000      8.700000  27697.00000
